# %% [markdown]
# # Test Setup Jupyter
# Verifica installazione e funzionalità base

# %%
import sys
print(f"Python: {sys.version}")
print(f"Jupyter: funzionante ✓")
# Out:
# Python: 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]
# Jupyter: funzionante ✓

# %%
# Test grafico (richiede matplotlib)
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

plt.plot(x, y, marker='o')
plt.title('Test Plot')
plt.xlabel('X')
plt.ylabel('Y²')
plt.grid(True)
plt.show()
